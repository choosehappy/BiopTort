# %%
from BiopTort import generate_mask, resize_image
from openslide import OpenSlide
from PIL.Image import Image
import numpy as np
import matplotlib.pyplot as plt

# %%
example_image_path = '/home/jackson/research/data/tortuosity_study/tortuosity_training_set/_1687415.svs'
osh = OpenSlide(example_image_path)
img = osh.read_region((0, 0), 2, osh.level_dimensions[2])
img: Image = resize_image(img, scalefactor=0.5)
numpy_img = np.array(img)[:,:,:3]

# %%
mask = generate_mask(numpy_img)

# %%
plt.imshow(mask)
